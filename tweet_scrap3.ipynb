# %%
import re
import csv
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import Chrome
import sqlite3
import pandas as pd


stocks=[[7,'indianstockmarket'],[8,'daytrading'],[9,'swingtrading']]


def get_tweet_data(lat,stock_id):
    try:
        st_id = str(stock_id)
    except:
        sleep(2)
        st_id = str(stock_id)
        
    try:
        username=lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div/div/div/div/div/a/div/div').text
    except:
        sleep(2)
        username=lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div/div/div/div/div/a/div/div').text
    try:    
        handle=lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div/div/div/div/div/a/div/div[2]').text
    except:
        sleep(2)
        handle=lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div/div/div/div/div/a/div/div[2]').text
        
    try:
        postdate=lat.find_element_by_xpath('//*[@id]/time').get_attribute('datetime')
    except:
        sleep(2)
        postdate=lat.find_element_by_xpath('//*[@id]/time').get_attribute('datetime')
    try:
        tweet = lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div[2]/div').text
    except:
        sleep(2)
        tweet = lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div[2]/div').text
    try:    
        bottomtweet= lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div[2]/div[2]').text
    except:
        sleep(2)
        bottomtweet= lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div[2]/div[2]').text
    try:    
        rep_text= lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div[2]/div[2]').text
    except:
        sleep(2)
        rep_text= lat.find_element_by_xpath('div/div/article/div/div/div/div[2]/div[2]/div[2]/div[2]').text
        
    text=tweet+bottomtweet
    try:
        reply = lat.find_element_by_xpath('//*[@id]/div[1]/div/div/div[2]').text
    except:
        sleep(2)
        reply = lat.find_element_by_xpath('//*[@id]/div[1]/div/div/div[2]').text
    try:    
        retweet = lat.find_element_by_xpath('//*[@id]/div[2]/div/div/div[2]').text
    except:
        sleep(2)
        retweet = lat.find_element_by_xpath('//*[@id]/div[2]/div/div/div[2]').text
    try:    
        likes = lat.find_element_by_xpath('//*[@id]/div[3]/div/div/div[2]').text
    except:
        sleep(2)
        likes = lat.find_element_by_xpath('//*[@id]/div[3]/div/div/div[2]').text
        
    message = (st_id,username,handle,postdate,text,reply,retweet,likes)
    return message



#navigating to twitter
driver = Chrome()
driver.get('https://twitter.com/i/flow/login')
sleep(6)
username = driver.find_element_by_xpath('//input[@name="username"]')
username.send_keys('rocketman20782078@gmail.com')
sleep(2)
clk = driver.find_element_by_xpath('//*[@id="layers"]/div[2]/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div')
clk.click()
sleep(3)
password = driver.find_element_by_xpath('//input[@name="password"]')
password.send_keys('Rocketman2078@twitter')
sleep(2)
clk1 = driver.find_element_by_xpath('//*[@id="layers"]/div[2]/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div')
clk1.click()
sleep(5)
pge = True

#till here opens twitter
tweet_data=[]
tweet_ids=set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

for i in range(len(stocks)):
    if pge == True:
        try:
            srch = driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[2]/div/div[2]/div/div/div/div[1]/div/div/div/form/div[1]/div/div/label/div[2]/div/input')
            srch.send_keys("#" + str(stocks[i][1]))
        except:
            sleep(2)
            srch = driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[2]/div/div[2]/div/div/div/div[1]/div/div/div/form/div[1]/div/div/label/div[2]/div/input')
            srch.send_keys("#" + str(stocks[i][1]))
        sleep(2)
        try:
            drpd=driver.find_element_by_xpath('//*[@id="typeaheadDropdown-1"]/div[2]/div/div')
            sleep(1)
            drpd.click()
        except:
            sleep(2)
            drpd=driver.find_element_by_xpath('//*[@id="typeaheadDropdown-1"]/div[2]/div/div')
            sleep(1)
            drpd.click()
            
        pge=False
    else:
        try:
            srch=driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/div/div/form/div[1]/div/div/label/div[2]/div/input')
            srch.click()
        except:
            sleep(2)
            srch=driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/div/div/form/div[1]/div/div/label/div[2]/div/input')
            srch.click()
            
        sleep(1)
        try:
            cros = driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/div/div/form/div[1]/div/div/label/div[3]/div/div')
            cros.click()
        except:
            sleep(2)
            cros = driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/div/div/form/div[1]/div/div/label/div[3]/div/div')
            cros.click()
            
        srch.send_keys("#" + str(stocks[i][1]))
        sleep(2)
        try:
            drpd1=driver.find_element_by_xpath('//*[@id="typeaheadDropdown-2"]/div[2]/div/div')
            drpd1.click()
        except:
            sleep(2)
            drpd1=driver.find_element_by_xpath('//*[@id="typeaheadDropdown-2"]/div[2]/div/div')
            drpd1.click()
            
        
        

    sleep(2)
    latest = driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[1]/div[2]/nav/div/div[2]/div/div[2]')
    latest.click()
    
    

    cnt=0
    
    while cnt<20:
        sleep(2)
        try:
            latest1 = driver.find_elements_by_xpath(r'html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div')
        except:
            sleep(3)
            latest1 = driver.find_elements_by_xpath(r'html/body/div/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div')
            
        for lat in latest1:
            sleep(1)
            try:
                data = get_tweet_data(lat,stocks[i][0])
            except:
                sleep(2)
                data = get_tweet_data(lat,stocks[i][0])
            if data:
                tweet_id = ''.join(data)
                if tweet_id not in tweet_ids:
                    tweet_ids.add(tweet_id)
                    tweet_data.append(data)
                
        scroll_attempt=0
        while True:
            sleep(1)
            driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')   
            sleep(5)
            cnt += 1
            curr_position = driver.execute_script("return window.pageYOffset;")
            sleep(1)
            if last_position == curr_position:
                scroll_attempt += 1
                if scroll_attempt>=3:
                    scrolling=False
                    break
                else:
                    sleep(5)
            else:
                last_position=curr_position
                break
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-1-92119ad92946> in <module>()
#      78 driver.get('https://twitter.com/i/flow/login')
#      79 sleep(6)
# ---> 80 username = driver.find_element_by_xpath('//input[@name="username"]')
#      81 username.send_keys('rocketman20782078@gmail.com')
#      82 sleep(2)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
with open(r'D:\datafiles\twitter_data\hashtag_data33.csv','w',newline='',encoding='utf_8') as f:
    header=['stock_id','username','handle','timestamp','text','reply','retweet','likes']
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerows(tweet_data)
